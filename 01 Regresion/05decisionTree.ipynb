# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Importar el Data Set
dataSet = pd.read_csv("Position_Salaries.csv")

# %%
print(dataSet.head())
print("Numero de filas: ", dataSet.shape[0])
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000
# Numero de filas:  10

# %%
X = dataSet.iloc[:, 1:2]
y = dataSet.iloc[:, 2]

# %%
print("type(X): ", type(X), ", Filas y Columnas X: ", X.shape, ", Filas de X: ", X.shape[0])
print("type(y): ", type(y), ", Filas y Columnas y: ", y.shape, ", Filas de y: ", y.shape[0])
# Out:
# type(X):  <class 'pandas.core.frame.DataFrame'> , Filas y Columnas X:  (10, 1) , Filas de X:  10
# type(y):  <class 'pandas.core.series.Series'> , Filas y Columnas y:  (10,) , Filas de y:  10

# %%
#Visualizar Conjunto de Datos Originales
from matplotlib.ticker import FuncFormatter, ScalarFormatter
plt.scatter(X, y, color = "red")
plt.title("Salario en funcion de Nivel")
plt.xlabel("Nivel")
plt.ylabel("Salario")

fmt = ScalarFormatter()
fmt.set_scientific(False)
plt.gca().yaxis.set_major_formatter(fmt)


plt.show()

# %%
#Ajustar el modelo Regression Tree al Data Set
from sklearn.tree import DecisionTreeRegressor
regression = DecisionTreeRegressor(random_state = 0)
regression.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
from sklearn.tree import plot_tree
plt.figure(fig
